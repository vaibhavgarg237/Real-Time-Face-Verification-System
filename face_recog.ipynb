# %% [markdown]
# Importing Libraries

# %%
import tensorflow as tf
import keras
from keras.models import Model,load_model,Sequential
from keras.layers import Flatten,Dense
from keras import backend as K
import pandas as pd
import numpy as np
import cv2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Loading Pre-Trained Model

# %%
face_model = load_model("C:\\Users\\YASH\\face recog tensorflow\\facenet_keras.h5")
# Out:
# C:\Users\YASH\Anaconda3\envs\Tensorflow-gpu\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
face_model.summary()
# Out:
# Model: "inception_resnet_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 160, 160, 3)  0
# __________________________________________________________________________________________________
# Conv2d_1a_3x3 (Conv2D)          (None, 79, 79, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_BatchNorm (BatchN (None, 79, 79, 32)   96          Conv2d_1a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_Activation (Activ (None, 79, 79, 32)   0           Conv2d_1a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# ...

# %%
face_cascade=cv2.CascadeClassifier('C:\\Users\\YASH\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml')

# %%
#FUNCTION TO ENCODE THE IMAGE
def img_encoding(image):
    img=np.resize(image,(160,160,3))
    img=img.reshape(1,160,160,3)
    #img_enc= (face_model.output,feed_dict={face_model.input:img})
    img_enc = face_model.predict(img)
    return img_enc

# %%
#FUNCTION TO VERIFY THE PERSON IDENTITY
def verify(check_img,identity,database):
    true_img=database[identity]
    err=np.linalg.norm(true_img.T - check_img.T)
    if (err<1.6):
        print('welcome '+str(identity))
        print(err)
    else:
        print('you are not allowed,please leave')
        print(err)

# %%
#DATABASE
def img_database(image,name):
    database[name]=img_encoding(image)

# %%
#MAIN FUNCTION 
def main_fun(input_img,name):
    check_img1=img_encoding(input_img)    
    verify(check_img1,name,database)

# %%
database={}

# %%
#TO STORE IMAGE IN THE DATABASE

img=cv2.imread('C:\\Users\\YASH\\face recog tensorflow\\yash1.jpg') # path to image to be stored in database
face=face_cascade.detectMultiScale(img,scaleFactor=1.05,minNeighbors=5)
for x,y,w,h in face:
    None
crop_img = img[y:y+h, x:x+w]
crop_img = (crop_img-127.5)/128
img_database((crop_img),"yash")

# %%
vid=cv2.VideoCapture(0)
while True:
    check,frame=vid.read()
    face=face_cascade.detectMultiScale(frame,scaleFactor=1.05,minNeighbors=5)
    for x,y,w,h in face:
        a=1
    
    crop_img = frame[y:y+h, x:x+w]
    #crop_img=frame
    crop_img1=(crop_img-127.5)/128
    main_fun(crop_img1,"yash")
    cv2.imshow("a",crop_img)
    key=cv2.waitKey(1)
    if(key==ord('q')):
        break;
        
vid.release()
cv2.destroyAllWindows()
# Out:
# welcome yash
# 0.9893638
# welcome yash
# 1.0807239
# welcome yash
# 1.1181219
# welcome yash
# 1.1416531
# welcome yash
# 1.094776
# welcome yash
# 1.1359456
# welcome yash
# 0.9554032
# welcome yash
# 1.0447972
# welcome yash
# 1.0048668
# welcome yash
# 1.1203398
# welcome yash
# 1.1384196
# welcome yash
# 0.9921987
# welcome yash
# 1.0420415
# welcome yash
# 1.5255203
# you are not allowed,please leave
# 1.881671
# you are not allowed,please leave
# 4.188234
# you are not allowed,please leave
# 3.3232808
# you are not allowed,please leave
# 3.3281505
# you are not allowed,please leave
# 3.3137128
# you are not allowed,please leave
# 3.7688413
# you are not allowed,please leave
# 3.8268888
# you are not allowed,please leave
# 3.7260785
# you are not allowed,please leave
# 3.2311146
# you are not allowed,please leave
# 3.4745622
# you are not allowed,please leave
# 3.9726145
# you are not allowed,please leave
# 3.8330297
# you are not allowed,please leave
# 3.8756104
# ...
